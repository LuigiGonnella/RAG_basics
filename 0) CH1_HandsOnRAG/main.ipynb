# %% [markdown]
# ## Basic RAG prompt

# %%
user_query = "What is the capital of France?"
docs = ["The capital of France is Paris"]

basic_prompt = """
Here is the user query: {QUERY},
Here are the useful docs: {DOCS},
Answer to the user query using the provided docs:
""".format(QUERY = user_query, DOCS = docs)

print(basic_prompt)
# Out:
# Here is the user query: What is the capital of France?,
# Here are the useful docs: ['The capital of France is Paris'],
# Answer to the user query using the provided docs:
